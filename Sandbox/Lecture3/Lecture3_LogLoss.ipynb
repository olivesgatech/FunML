# %%
# Logistic loss functions
def log_loss_y1(z):
    return -np.log(z)

def log_loss_y0(z):
    return -np.log(1 - z)

# Define a range of z values (predicted probabilities)
z_values = np.linspace(0.01, 0.99, 400)  # Avoid exactly 0 and 1 to prevent log(0)

# Calculate losses for y = 1 and y = 0
loss_y1 = log_loss_y1(z_values)
loss_y0 = log_loss_y0(z_values)

# Creating the side-by-side plots
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plotting the loss for y = 1
axes[0].plot(z_values, loss_y1, label=r'$LL(y=1, z)$', color='blue')
axes[0].set_title("Desired Loss Function for y = 1")
axes[0].set_xlabel('Predicted Probability z')
axes[0].set_ylabel('Loss LL(y=1, z)')
axes[0].grid(True)
axes[0].legend()

# Plotting the loss for y = 0
axes[1].plot(z_values, loss_y0, label=r'$LL(y=0, z)$', color='red')
axes[1].set_title("Desired Loss Function for y = 0")
axes[1].set_xlabel('Predicted Probability z')
axes[1].set_ylabel('Loss LL(y=0, z)')
axes[1].grid(True)
axes[1].legend()

# Adjust layout to prevent overlap
plt.tight_layout()

plt.show()

# %%
# Logistic loss functions
def log_loss_y1(z):
    return -np.log(z)

def log_loss_y0(z):
    return -np.log(1 - z)

# Define a range of z values (predicted probabilities)
z_values = np.linspace(0.01, 0.99, 400)  # Avoid exactly 0 and 1 to prevent log(0)

# Calculate losses for y = 1 and y = 0
loss_y1 = log_loss_y1(z_values)
loss_y0 = log_loss_y0(z_values)

# Plotting the combined loss function
plt.figure(figsize=(10, 6))

plt.plot(z_values, loss_y1, label=r'$LL(y=1, z) = -\log(z)$', color='blue')
plt.plot(z_values, loss_y0, label=r'$LL(y=0, z) = -\log(1 - z)$', color='red')

# Add vertical lines for clarity at z = 0 and z = 1
plt.axvline(0.5, color='black', linestyle=':')

# Labels and title
plt.title("Log Loss Function for (x, y)")
plt.xlabel('Predicted Probability z')
plt.ylabel('Loss LL(y, z)')
plt.grid(True)
plt.legend()

plt.show()
